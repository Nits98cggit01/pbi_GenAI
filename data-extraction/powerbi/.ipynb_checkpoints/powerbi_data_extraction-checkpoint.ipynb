# %%
# %run pbi_visual_extracts.ipynb
# Out:
# A local browser window will open for interactive sign in.
#
# Interactive authentication successfully completed.
# You are now logged in.
#
# The result should be passed only to trusted code in your notebook.

# %%
ROOT_PATH = input("Enter the path where you wanted to store the data: ")
report_name = input("Enter the report name: ")
url = input("Enter the url of the power bi report: ")
# Out:
# Enter the path where you wanted to store the data: C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\powerbi-usecase\summarization\bulk-file-handling\report-narration
# Enter the report name: corporateSpend
# Enter the url of the power bi report: https://app.powerbi.com/groups/1e4c934b-97de-47ce-bfa0-e64ed96aeb24/reports/8722099b-3938-4787-b720-d2e8065c0233/ReportSection2?experience=power-bi&clientSideAuth=0&refreshAccessToken=true

# %%
report = render_pbi_report(url)
report
# Out:
# Report()

# %%
df_name = input("Enter the dataframe name: ")
# Out:
# Enter the dataframe name: planVariance

# %%
df2 =  get_visual_data(report,df_name,ROOT_PATH,report_name)
df2
# Out:
# Entered try loop 0 : ReportSection32e53fe7c4f4cd87dd85 ; VisualContainer10
# C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\powerbi-usecase\summarization\bulk-file-handling\report-narration\corporateSpend\read_folder\corporateSpend_Plan Variance Analysis_Var Plan % by Business Area.csv
# Entered try loop 1 : ReportSection32e53fe7c4f4cd87dd85 ; VisualContainer11
# C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\powerbi-usecase\summarization\bulk-file-handling\report-narration\corporateSpend\read_folder\corporateSpend_Plan Variance Analysis_Var Plan by Business Area.csv
# Entered try loop 2 : ReportSection32e53fe7c4f4cd87dd85 ; VisualContainer9
# C:\Users\NITINS\OneDrive - Capgemini\CAPGEMINI\PROJECT\GEN AI\powerbi-usecase\summarization\bulk-file-handling\report-narration\corporateSpend\read_folder\corporateSpend_Plan Variance Analysis_Matrix.csv
# Entered try loop 3 : ReportSection32e53fe7c4f4cd87dd85 ; VisualContainer8
# ...

# %%
def get_consolidated_pgviz(df1,df2):
    final_df = pd.concat([df1,df2], ignore_index = True)
    file_path = os.path.join(ROOT_PATH,report_name, f"{report_name}_MasterData.csv")
    final_df.to_csv(file_path)
    return final_df

final_df = get_consolidated_pgviz(df1,df2)
final_df
# Out:
#                               Page_id               Page_Name  \
# 0                      ReportSection2          IT Spend Trend
# 1                      ReportSection2          IT Spend Trend
# 2                      ReportSection2          IT Spend Trend
# 3                      ReportSection2          IT Spend Trend
# 4                      ReportSection2          IT Spend Trend
# 5   ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 6   ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 7   ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 8   ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 9   ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 10  ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 11  ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 12  ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
# 13  ReportSection32e53fe7c4f4cd87dd85  Plan Variance Analysis
#
# ...
